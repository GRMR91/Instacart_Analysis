# %%
import pandas as pd
import numpy as np
import os

# %%
path = r"C:\Users\grace\CareerFoundry\CF.mod4 - Python Fundamentals for Data Analysts"

# %%
orders_products_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Cleaned Data', 'orders_products_merged_v2.pkl'))

# %%
orders_products_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                  8                     NaN          True         196
# 1                  7                    15.0         False         196
# 2                 12                    21.0         False         196
# 3                  7                    29.0         False         196
# 4                 15                    28.0         False         196
#
#    add_to_cart_order  reordered _merge product_name  aisle_id  department_id  \
# ...

# %%
df = orders_products_merged[:1000000]

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                  8                     NaN          True         196
# 1                  7                    15.0         False         196
# 2                 12                    21.0         False         196
# 3                  7                    29.0         False         196
# 4                 15                    28.0         False         196
#
#    add_to_cart_order  reordered _merge product_name  aisle_id  department_id  \
# ...

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.groupby('department_id').agg({ 'order_number' : ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
# Creating a 'max_order' column, grouping the df by the user_id and transforming the order_number column by appling the .max function
orders_products_merged['max_order'] = orders_products_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
orders_products_merged.head(100)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# ..       ...      ...      ...           ...                 ...
# 95   3226575      360    prior             1                   5
# 96   1469869      377    prior             3                   5
# 97   1927023      387    prior             2                   4
# 98    858092      420    prior             4                   1
# 99    119314      420    prior             5                   3
#
#     order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                   8                     NaN          True         196
# ...

# %%
pd.options.display.max_rows = None

# %%
orders_products_merged.head(100)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# ...

# %% [markdown]
#     # Assigning flag to 'max_order' column

# %%
orders_products_merged.loc[orders_products_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
orders_products_merged.loc[(orders_products_merged['max_order'] <= 40) & (orders_products_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
orders_products_merged.loc[orders_products_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
orders_products_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15877395
# Loyal customer      10284396
# New customer         6244250
# Name: loyalty_flag, dtype: int64

# %%
orders_products_merged['order_number'].dtype
# Out:
# dtype('int64')

# %%
orders_products_merged.head(100)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# ...

# %%
orders_products_merged = orders_products_merged.drop(columns = ['loyalty flag'])

# %%
orders_products_merged.head(100)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# ...

# %%
orders_products_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15877395
# Loyal customer      10284396
# New customer         6244250
# Name: loyalty_flag, dtype: int64

# %%
orders_products_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...
